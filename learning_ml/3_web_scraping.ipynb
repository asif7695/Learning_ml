# %%
# !pip install requests
# !pip install bs4
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
final = pd.DataFrame()
for j in range(1,10):
  webpage = requests.get(f"https://remote.co/remote-jobs/accounting?page={j}").text
  soup = BeautifulSoup(webpage, 'lxml')
  jobs = soup.find_all('div',class_="sc-14nyru2-2 fmkHkh")
  job_title = []
  location = []
  time = []
  salary = []

  for i in jobs:
    job_title.append(i.find('a').text)
    location.append(i.find('span',class_="sc-jv5lm6-10 efTTiy allowed-location").text)
    time.append(i.find('li',class_="sc-jv5lm6-9 jxMgfz tag-name").text)
  d = {'job_title':job_title,'location':location,'tags':time}
  df = pd.DataFrame(d)
  final = pd.concat([final,df])

# %%
final
# Out:
#                                             job_title  \
# 0                             Senior Business Analyst
# 1                                 Financial Counselor
# 2                                     Finance Manager
# 3               Fund Balance with Treasury IT Analyst
# 4   Senior Compliance Analyst, Financial Crimes Co...
# ..                                                ...
# 45                  Data Governance Controls, Analyst
# 46                            Claims Finance Director
# 47  Planning, Strategy and Information Services An...
# 48                                  Senior Accountant
# 49  Associate Quality Assurance Engineer for Suppl...
#
#                                              location                tags
# 0                         Hybrid Remote in Tustin, CA  Hybrid Remote Work
# 1                    Hybrid Remote in Zephyrhills, FL  Hybrid Remote Work
# 2                      Hybrid Remote in Billerica, MA  Hybrid Remote Work
# ...
